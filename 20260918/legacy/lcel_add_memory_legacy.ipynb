# %%
from operator import itemgetter
from langchain_classic.memory import ConversationBufferMemory
from langchain_core.prompts import ChatPromptTemplate,MessagesPlaceholder
from langchain_core.runnables import RunnableLambda, RunnablePassthrough
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
load_dotenv()
model = ChatOpenAI()

# %%
prompt = ChatPromptTemplate.from_messages(
    [
        ("system","You are a helpful chatbot"),
        MessagesPlaceholder(variable_name="chat_history"),
        ("human","{input}"),
    ]
)

# %%
memory = ConversationBufferMemory(return_messages=True, memory_key="chat_history")
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1812\2844409624.py:1: LangChainDeprecationWarning: The class `ConversationBufferMemory` was deprecated in LangChain 0.3.1 and will be removed in 2.0.0. Use `langchain.agents.create_agent` instead. For agents that need to remember prior interactions, use `create_agent` with checkpointing or the `Store` API. See https://docs.langchain.com/oss/python/langchain/short-term-memory and https://docs.langchain.com/oss/python/langchain/long-term-memory
#   memory = ConversationBufferMemory(return_messages=True, memory_key="chat_history")

# %%
memory.load_memory_variables({})
# Out:
# {'chat_history': []}

# %%
runnable = RunnablePassthrough.assign(
    chat_history=RunnableLambda(memory.load_memory_variables)
    |itemgetter("chat_history")
)
runnable.invoke({"input":"hi"})
# Out:
# {'input': 'hi', 'chat_history': []}

# %%
chat_history=RunnableLambda(memory.load_memory_variables)

# %%
# runnable = RunnablePassthrough.assign(
#     chat_history=RunnableLambda(memory.load_memory_variables)
#     #    |itemgetter("chat_history")
# )
# runnable.invoke({"input":"hi"})
# Out:
# {'input': 'hi', 'chat_history': {'chat_history': []}}

# %%
chain = runnable | prompt | model

# %%
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful chatbot"),
    MessagesPlaceholder(variable_name="chat_history"),
    ("human","{input}"),
])

# %%
response = chain.invoke({"input":"만나서 반갑습니다. 제 이름은 테디입니다."})
print(response.content)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 response = chain.invoke({"input":"만나서 반갑습니다. 제 이름은 테디입니다."})
#       2 print(response.content)
#
# File d:\hanwha_0902\venv\.venv\Lib\site-packages\langchain_core\runnables\base.py:3456, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3454                 input_ = context.run(step.invoke, input_, config, **kwargs)
#    3455             else:
# -> 3456                 input_ = context.run(step.invoke, input_, config)
#    3457 # finish the root run
#    3458 except BaseException as e:
#
# File d:\hanwha_0902\venv\.venv\Lib\site-packages\langchain_core\prompts\base.py:230, in BasePromptTemplate.invoke(self, input, config, **kwargs)
#     228 if self.tags:
#     229     config["tags"] += self.tags
# --> 230 return self._call_with_config(
#     231     self._format_prompt_with_error_handling,
#     232     input,
#     233     config,
#     234     run_type="prompt",
#     235     serialized=self._serialized,
#     236 )
#
# File d:\hanwha_0902\venv\.venv\Lib\site-packages\langchain_core\runnables\base.py:2301, in Runnable._call_with_config(self, func, input_, config, run_type, serialized, **kwargs)
#    2297     child_config = patch_config(config, callbacks=run_manager.get_child())
#    2298     with set_config_context(child_config) as context:
#    2299         output = cast(
#    2300             "Output",
# -> 2301             context.run(
#    2302                 call_func_with_variable_args,  # type: ignore[arg-type]
#    2303                 func,
#    2304                 input_,
#    2305                 config,
#    2306                 run_manager,
#    2307                 **kwargs,
#    2308             ),
#    2309         )
#    2310 except BaseException as e:
#    2311     run_manager.on_chain_error(e)
#
# File d:\hanwha_0902\venv\.venv\Lib\site-packages\langchain_core\runnables\config.py:526, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     524 if run_manager is not None and accepts_run_manager(func):
#     525     kwargs["run_manager"] = run_manager
# --> 526 return func(input, **kwargs)
#
# File d:\hanwha_0902\venv\.venv\Lib\site-packages\langchain_core\prompts\base.py:201, in BasePromptTemplate._format_prompt_with_error_handling(self, inner_input)
#     197 def _format_prompt_with_error_handling(
#     198     self, inner_input: builtins.dict[str, Any]
#     199 ) -> PromptValue:
#     200     inner_input_ = self._validate_input(inner_input)
# --> 201     return self.format_prompt(**inner_input_)
#
# File d:\hanwha_0902\venv\.venv\Lib\site-packages\langchain_core\prompts\chat.py:735, in BaseChatPromptTemplate.format_prompt(self, **kwargs)
#     727 def format_prompt(self, **kwargs: Any) -> ChatPromptValue:
#     728     """Format prompt.
#     729
#     730     Should return a `ChatPromptValue`.
#    (...)    733         **kwargs: Keyword arguments to use for formatting.
#     734     """
# --> 735     messages = self.format_messages(**kwargs)
#     736     return ChatPromptValue(messages=messages)
#
# File d:\hanwha_0902\venv\.venv\Lib\site-packages\langchain_core\prompts\chat.py:1195, in ChatPromptTemplate.format_messages(self, **kwargs)
#    1191     result.extend([message_template])
#    1192 elif isinstance(
#    1193     message_template, (BaseMessagePromptTemplate, BaseChatPromptTemplate)
#    1194 ):
# -> 1195     message = message_template.format_messages(**kwargs)
#    1196     result.extend(message)
#    1197 else:
#
# File d:\hanwha_0902\venv\.venv\Lib\site-packages\langchain_core\prompts\chat.py:186, in MessagesPlaceholder.format_messages(self, **kwargs)
#     181 if not isinstance(value, list):
#     182     msg = (
#     183         f"variable {self.variable_name} should be a list of base messages, "
#     184         f"got {value} of type {type(value)}"
#     185     )
# --> 186     raise ValueError(msg)  # noqa: TRY004
#     187 value = convert_to_messages(value)
#     188 if self.n_messages:
#
# ValueError: variable chat_history should be a list of base messages, got {'chat_history': []} of type <class 'dict'>
