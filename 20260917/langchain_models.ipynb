# %%
from dotenv import load_dotenv
from langchain_teddynote import logging

load_dotenv()
logging.langsmith("CH04-Models")
# Out:
# LangSmith 추적을 시작합니다.
# [프로젝트명]
# CH04-Models

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate

llm = ChatOpenAI(model="gpt-4o-mini")

prompt = PromptTemplate.from_template("{country}에 대해서 200자 내외로 요약해줘.")
chain = prompt | llm

# %%
# %%time
response = chain.invoke({"country":"한국"})
print(response.content)
# Out:
# 한국은 동아시아에 위치한 한반도의 국가로, 남한과 북한으로 나뉘어 있습니다. 고유의 역사와 문화를 가지고 있으며, 현대에는 정보기술, 자동차, K-팝 등으로 세계적인 영향력을 미치고 있습니다. 서울은 수도로, 전통과 현대가 조화롭게 어우러진 도시입니다. 또한 다채로운 자연경관과 맛있는 음식이 특징인 곳입니다.
# CPU times: total: 31.2 ms
# Wall time: 1.59 s

# %%
# %%time
from langchain_core.globals import set_llm_cache
from langchain_core.caches import InMemoryCache

set_llm_cache(InMemoryCache())

response = chain.invoke({"country":"한국"})
print(response.content)
# Out:
# 한국은 동아시아에 위치한 한반도의 국가로, 서울이 수도입니다. 고유한 문화와 전통을 보존하면서도 현대화된 경제와 기술로 발전하였습니다. K-팝, 영화, 음식 등이 전 세계적으로 인기를 끌며, 강력한 IT 산업과 교육 시스템을 갖추고 있습니다. 한편, 북한과의 분단 문제는 여전히 중요한 이슈입니다.
# CPU times: total: 15.6 ms
# Wall time: 1.32 s

# %%
# %%time
response = chain.invoke({"country": "한국"})
print(response.content)
# Out:
# 한국은 동아시아에 위치한 한반도의 국가로, 서울이 수도입니다. 고유한 문화와 전통을 보존하면서도 현대화된 경제와 기술로 발전하였습니다. K-팝, 영화, 음식 등이 전 세계적으로 인기를 끌며, 강력한 IT 산업과 교육 시스템을 갖추고 있습니다. 한편, 북한과의 분단 문제는 여전히 중요한 이슈입니다.
# CPU times: total: 15.6 ms
# Wall time: 7.39 ms

# %%
from langchain_community.cache import SQLiteCache
from langchain_core.globals import set_llm_cache
import os

if not os.path.exists("cache"):
    os.makedirs("cache")

set_llm_cache(SQLiteCache(database_path="cache/llm_cache.db"))

# %%
# %%time
response = chain.invoke({"country": "한국"})
print(response.content)
# Out:
# 한국은 동아시아에 위치한 반도 국가로, 북한과 남한으로 나뉘어 있습니다. 서울은 수도이자 경제 중심지이며, K-팝, 한류 문화로 세계적으로 알려져 있습니다. 역사적으로 고대 왕국부터 현대 국가로 발전하였고, 뛰어난 교육 시스템과 기술 혁신으로 주목받고 있습니다. 풍부한 자연경관과 전통 문화, 맛있는 음식도 매력적입니다.
# CPU times: total: 62.5 ms
# Wall time: 1.59 s

# %%
# %%time
response = chain.invoke({"country": "한국"})
print(response.content)
# Out:
# 한국은 동아시아에 위치한 반도 국가로, 북한과 남한으로 나뉘어 있습니다. 서울은 수도이자 경제 중심지이며, K-팝, 한류 문화로 세계적으로 알려져 있습니다. 역사적으로 고대 왕국부터 현대 국가로 발전하였고, 뛰어난 교육 시스템과 기술 혁신으로 주목받고 있습니다. 풍부한 자연경관과 전통 문화, 맛있는 음식도 매력적입니다.
